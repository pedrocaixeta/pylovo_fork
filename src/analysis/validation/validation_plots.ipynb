# %%
from src.analysis.utils import *
from pandapower.plotting.plotly import simple_plotly

# %%
from src.analysis.utils import *
from pandapower.plotting.plotly import simple_plotly

net, file_path = read_net_json()

# The line geodata index must match the line index for plotting. We assign the index from net.line to net.line_geodata.
if not net.line.empty and not net.line_geodata.empty:
            net.line_geodata.index = net.line.index

# We use 'on_map=False' because the coordinates are Cartesian, not Lat/Lon.
fig = simple_plotly(net, on_map=False, map_style="open-street-map")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 # The line geodata index must match the line index for plotting. We assign the index from net.line to net.line_geodata.
#       4 if not net.line.empty and not net.line_geodata.empty:
# ----> 5             net.line_geodata.index = net.line.index
#       7 # We use 'on_map=False' because the coordinates are Cartesian, not Lat/Lon.
#       8 fig = simple_plotly(net, on_map=False, map_style="open-street-map")
#
# File ~/git/github/pylovo/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...
