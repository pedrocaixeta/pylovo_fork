# %%
import pandapower as pp

from pylovo.plotting import draw_tree_network
from pylovo.plotting import draw_tree_network_improved_spacing
from pylovo.plotting import plot_simple_grid
from src.grid_generator import GridGenerator

# %%
plz = "80803"
kcid = 1
bcid = 7

# %%
plot_simple_grid(plz, kcid, bcid)
# Out:
# 2025-06-12 16:44:40,657 - DatabaseClient - ERROR - Grid not found for plz=80803, kcid=7, bcid=1, version_id=1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_simple_grid(plz, bcid, kcid)
#
# File ~/git/github/pylovo/plotting/plot_networks.py:107, in plot_simple_grid(plz, kcid, bcid)
#     103 def plot_simple_grid(plz: str, kcid: int, bcid: int) -> None:
#     104     """
#     105     plots network on a plank base
#     106     """
# --> 107     net = read_net_with_grid_generator(plz=plz, kcid=kcid, bcid=bcid)
#     108     simple_plotly(net)
#
# File ~/git/github/pylovo/plotting/plot_networks.py:29, in read_net_with_grid_generator(plz, kcid, bcid)
#      27 gg = GridGenerator(plz=plz)
#      28 dbc_client = gg.dbc
# ---> 29 net = dbc_client.read_net(plz=str(int(plz)), kcid=kcid, bcid=bcid)
#      30 return net
#
# ...

# %%
gg = GridGenerator(plz=plz)
pg = gg.dbc
net = pg.read_net_db(str(int(plz)), kcid, bcid)
G = pp.topology.create_nxgraph(net)
draw_tree_network(G)

# %%
draw_tree_network_improved_spacing(G)

# %%
(G.degree(0))

# %%
degrees = [val for (node, val) in G.degree()]
degrees
