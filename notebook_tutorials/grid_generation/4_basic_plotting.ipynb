# %% [markdown]
# # Plotting network parameters of plz

# %%
import warnings

from src.grid_generator import GridGenerator

warnings.filterwarnings('ignore')

# %%
plz = 80803

# %%
plot_pie_of_trafo_cables(plz)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_pie_of_trafo_cables(plz)
#
# File ~/git/github/pylovo/plotting/plot_for_plz.py:27, in plot_pie_of_trafo_cables(plz)
#      25 gg = GridGenerator(plz=plz)
#      26 dbc_client = gg.dbc
# ---> 27 data_list, data_labels, trafo_dict = dbc_client.read_per_trafo_dict(plz=plz)
#      28 fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 4))
#      29 # Plot Transformer size distribution
#
# File ~/git/github/pylovo/pylovo/database_modules/databaseRead.py:418, in ReadMixin.read_per_trafo_dict(self, plz)
#     415 result = self.cur.fetchall()
#     417 # Sort all parameters according to transformer size
# --> 418 load_dict = dict(sorted(result[0][0].items(), key=lambda x: int(x[0])))
#     419 bus_dict = dict(sorted(result[0][1].items(), key=lambda x: int(x[0])))
#     420 peak_dict = dict(sorted(result[0][2].items(), key=lambda x: int(x[0])))
#
# IndexError: list index out of range

# %%
plot_hist_trafos(plz)

# %%
plot_boxplot_plz(plz)

# %%
plot_trafo_on_map(plz)

# %%
plot_cable_length_of_types(plz)
